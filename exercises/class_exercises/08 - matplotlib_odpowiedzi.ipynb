# %% [markdown]
# # Ćwiczenia z wykorzystaniem Matplotlib
#
# W ramach tego kursu nauczysz się tworzyć zaawansowane wizualizacje danych przy użyciu Matplotlib.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Ćwiczenie 1: Wygenerowanie funkcji sinus, cosinus i ich sumy
#
# Użyj Matplotlib do wygenerowania i wyświetlenia wykresów funkcji sinus, cosinus oraz ich sumy na jednym wykresie.

# %%
x = np.linspace(0, 2 * np.pi, 100)
y_sin = np.sin(x)
y_cos = np.cos(x)
y_sum = y_sin + y_cos

plt.figure(figsize=(10, 6))
plt.plot(x, y_sin, label='sin(x)')
plt.plot(x, y_cos, label='cos(x)')
plt.plot(x, y_sum, label='sin(x) + cos(x)', linestyle='--')
plt.title('Wykres funkcji sinus, cosinus i ich sumy')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Canvas(header_visible=True, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back…

# %% [markdown]
# ## Ćwiczenie 2: Generowanie przesuniętej w fazie sumy funkcji sinus i cosinus
#
# Zmodyfikuj poprzedni kod, aby suma funkcji sinus i cosinus była przesunięta w fazie o \( \pi/4 \).

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2 * np.pi, 100)
y_sin = np.sin(x)
y_cos = np.cos(x)
y_sum_phase_shift = y_sin + y_cos + np.sin(x + np.pi/4)

plt.figure(figsize=(10, 6))
plt.plot(x, y_sin, label='sin(x)')
plt.plot(x, y_cos, label='cos(x)')
plt.plot(x, y_sum_phase_shift, label='sin(x) + cos(x) + sin(x + π/4)', linestyle='--')
plt.title('Wykres funkcji sinus, cosinus i przesuniętej w fazie sumy')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Canvas(header_visible=True, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back…

# %% [markdown]
# ## Cwiczenie 3: Wykorzystanie subplotów do prezentacji funkcji matematycznych
#
# Stwórz trzy subplots pionowo: pierwszy dla funkcji sinus, drugi dla cosinus, trzeci dla ich sumy oraz sumy ich kwadratów. Każdy wykres powinien mieć odpowiednie etykiety, podpisy osi, siatkę i legendę.

# %%
# Definicja danych
x = np.linspace(0, 2 * np.pi, 100)
sin_x = np.sin(x)
cos_x = np.cos(x)
sum_sin_cos = sin_x + cos_x
sum_squares = sin_x**2 + cos_x**2

# Tworzenie subplots
fig, axs = plt.subplots(3, 1, figsize=(8, 12))

# Wykres dla funkcji sinus
axs[0].plot(x, sin_x, label='sin(x)', color='blue')
axs[0].set_title('Funkcja Sinus')
axs[0].set_ylabel('sin(x)')
axs[0].legend()
axs[0].grid(True)

# Wykres dla funkcji cosinus
axs[1].plot(x, cos_x, label='cos(x)', color='red')
axs[1].set_title('Funkcja Cosinus')
axs[1].set_ylabel('cos(x)')
axs[1].legend()
axs[1].grid(True)

# Wykres dla sumy funkcji sinus i cosinus oraz sumy ich kwadratów
axs[2].plot(x, sum_sin_cos, label='sin(x) + cos(x)', color='green')
axs[2].plot(x, sum_squares, label='sin(x)^2 + cos(x)^2', color='purple', linestyle='--')
axs[2].set_title('Suma funkcji i suma kwadratów')
axs[2].set_xlabel('x')
axs[2].set_ylabel('Wartość')
axs[2].legend()
axs[2].grid(True)

plt.tight_layout()
plt.show()
# Out:
# Canvas(header_visible=True, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back…

# %% [markdown]
# ## Ćwiczenie 5: Wykresy z parametrami linii i punktami danych
#
# twórz wykres, który będzie zawierał dwie funkcje: \( e^{-x} \) i \( \log(x+1) \). Użyj różnych stylów linii, kolorów i markerów dla każdej z funkcji. Dodaj legendę oraz odpowiednie etykiety dla osi.

# %%
# Definicja danych
x = np.linspace(0, 2, 100)
y_exp = np.exp(-x)
y_log = np.log(x + 1)

# Tworzenie wykresu
plt.figure(figsize=(10, 6))

# Rysowanie funkcji e^(-x)
plt.plot(x, y_exp, label='$e^{-x}$', linestyle='-', linewidth=2, color='blue', marker='o', markersize=5)

# Rysowanie funkcji log(x+1)
plt.plot(x, y_log, label='$\log(x+1)$', linestyle='--', linewidth=2, color='red', marker='s', markersize=5)

# Dodanie legendy, etykiet i siatki
plt.title('Wykres funkcji $e^{-x}$ i $\log(x+1)$')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)

# Wyświetlenie wykresu
plt.show()
# Out:
# Canvas(header_visible=True, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back…

# %% [markdown]
# ## Ćwiczenie 6: Wykresy punktowe (Scatter Plots)
#
# Stwórz wykres punktowy przedstawiający zależności między dwoma zestawami danych.
#
# Użyj różnych kolorów dla punktów w zależności od ich wartości.
#
# Dodaj kolorową legendę, która pomoże zrozumieć zależności wartości.
#
# Dla uzyskania efektu kolorystycznego dodaj parametr alpha=0.5 - transparentność.

# %% [markdown]
# W funkcji ```scatter()``` z Matplotlib, parametry c (color) i s (size) są wykorzystywane do kontrolowania kolorów i rozmiarów poszczególnych punktów na wykresie. Umożliwiają one dodanie dodatkowej warstwy informacji do wizualizacji danych, co jest szczególnie przydatne przy eksploracji złożonych zbiorów danych.
#
# ### Parametr c (color):
#
# - Opis: Parametr c pozwala na określenie kolorów punktów na wykresie. Można podać pojedynczy kolor dla wszystkich punktów lub listę/serię kolorów, co pozwala na ich indywidualne dostosowanie.
# - Zastosowanie: Używając c z wartościami numerycznymi i mapą kolorów (cmap), możemy kodować dane numeryczne jako kolory, co ułatwia zrozumienie zależności i rozkładów w danych.
#
# ### Parametr s (size)
# - Opis: Parametr s kontroluje rozmiar punktów na wykresie. Podobnie jak w przypadku c, można ustawić stały rozmiar dla wszystkich punktów lub zdefiniować różne rozmiary dla każdego punktu indywidualnie, co może być zależne od innej zmiennej w danych.
# - Zastosowanie: Rozmiar punktów można wykorzystać do przedstawienia dodatkowego wymiaru danych, na przykład wielkości populacji, wydatków, częstotliwości itp., co pozwala na łatwiejsze wychwycenie ważnych cech w danych.

# %%
# Generowanie losowych danych
x = np.random.rand(50)
y = np.random.rand(50)
colors = np.random.rand(50)  # Kolory punktów będą zależały od losowej wartości
sizes = 500 * np.random.rand(50)  # Rozmiary punktów zależne od losowej wartości

# Tworzenie wykresu
plt.figure(figsize=(10, 6))
scatter = plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='viridis')
plt.colorbar(scatter)  # Dodanie paska kolorów
plt.title('Wykres punktowy z różnymi kolorami i rozmiarami punktów')
plt.xlabel('Wartość x')
plt.ylabel('Wartość y')
plt.grid(True)

# Wyświetlenie wykresu
plt.show()
# Out:
# Canvas(header_visible=True, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back…

# %% [markdown]
# ## Ćwiczenie 7: Wykorzystanie różnych map kolorów do wizualizacji danych 2D
#
# Utwórz wykres z użyciem funkcji `imshow()`, na którym pokażesz tę samą macierz danych z wykorzystaniem różnych map kolorów.

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.rand(10, 10)
colormaps = ['viridis', 'plasma', 'inferno', 'magma', 'cividis']

fig, axs = plt.subplots(1, 5, figsize=(15, 3))
for ax, cmap in zip(axs, colormaps):
    im = ax.imshow(data, cmap=cmap)
    ax.set_title(cmap)
    ax.axis('off')
fig.colorbar(im, ax=axs, orientation='horizontal', fraction=.1)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_73085/2603070537.py:13: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /home/kkingstoun/software/anaconda3/envs/numba_sprawna/lib/python3.10/site-packages/ipympl/backend_nbagg.py:336: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.figure.savefig(buf, format='png', dpi='figure')
# Canvas(header_visible=True, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back…
